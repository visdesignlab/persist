# %%
import altair as alt
import pandas as pd

# Import the extension. This is the line that enables everything.
import persist_ext as PR

PR.enable('altair')
# Out:
# Loaded PersIst extension version 1.3.0
# Extension enabled for altair

# %%
df = pd.read_csv('./season_phase_data.csv')
df
# Out:
#      Unnamed: 0        Date     Region                              Place  \
# 0             0  2014-02-10     Uintas  Uintas Lake Creek Avalanche Cycle
# 1             1  2023-01-27      Provo                            Bunnels
# 2             2  2016-01-24  Salt Lake                       Lambs Canyon
# 3             3  2014-05-19  Salt Lake                         Big Willow
# 4             4  2010-12-19      Logan                      Beaver Canyon
# ..          ...         ...        ...                                ...
# 588         588  2021-12-15      Logan                    Tony Grove Lake
# 589         589  2023-03-16  Salt Lake                      Pioneer Ridge
# 590         590  2016-12-09  Salt Lake                       No Name Bowl
# 591         591  2009-12-17     Uintas                        Double Hill
# 592         592  2018-11-25  Salt Lake        Reynolds East Face Shoulder
#
#          Trigger   Trigger: additional info                   Weak Layer  \
# ...

# %%
PR.vis.scatterplot(df, "Elevation_Feet:Q", "Depth_Inches:Q")
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting
