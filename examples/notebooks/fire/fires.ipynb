# %%
import altair as alt
import pandas as pd
import persist_ext as PR

PR.enable("altair")
# Out:
# Loaded PersIst extension version 1.2.0
# Extension enabled for altair

# %%
fires_df = pd.read_csv("./fire_earlier.csv")
fires_df
# Out:
#      STATE                COUNTY   LATITUDE   LONGITUDE  FIRE_SIZE  \
# 0       GA               Baldwin  33.051434  -83.073473       6.65
# 1       WV            Monongalia  39.566542  -80.057181       5.00
# 2       WV                 Logan  37.940879  -82.022978      61.00
# 3       MS                Copiah  31.809243  -90.717968       2.00
# 4       WA                    37  47.037222 -120.950556       0.20
# ...    ...                   ...        ...         ...        ...
# 4995    GA               Pulaski  32.269900  -83.489800       1.33
# 4996    GA  Brantley              31.189600  -82.177600       3.30
# 4997    NM            Rio Arriba  36.710000 -107.588400       0.30
# 4998    GA               Baldwin  33.117973  -83.290426       2.09
# 4999    MS              Harrison  30.572629  -89.209724       3.00
#
#       CAUSE_CODE     CAUSE_DESCR  DISCOVERY_DATE  DISCOVERY_TIME  CONT_DATE  \
# 0            5.0  Debris Burning       2452456.5            1610  2452456.5
# ...

# %%
selector = alt.selection_point(name="sel", encodings=["x"])

alt.Chart(fires_df).mark_bar().encode(
    x="STATE",
    y="count()"
).add_params(selector)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting
