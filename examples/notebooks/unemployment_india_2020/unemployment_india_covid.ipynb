# %%
import altair as alt
import pandas as pd

# Import the extension. This is the line that enables everything.
import persist_ext as PR

PR.enable('altair')
# Out:
# Loaded PersIst extension version 1.3.0
# Extension enabled for altair

# %%
df = pd.read_csv("./unemployment_india_2020.csv")
df.head()

# %%
df.info()

# %% [markdown]
# The 2020 data doesn't have missing values, but the column names are hard to use and column name `Region` is accidently duplicated. One of the `Region` column's is actually `States`. We can rename them using persist.

# %%
alt.Chart(df).mark_bar().encode(
    x="Region:N",
    y="count()",
)

# %%
renamed_df

# %%
renamed_df[" Frequency"].info()

# %% [markdown]
# The frequency column has just one value. We should also remove the states with missing records.

# %%
selector = alt.selection_point(name="selector", encodings=["x"])

alt.Chart(renamed_df, name="bars").mark_bar().encode(x="States:N",
            y="count()",
            color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
           ).add_params(selector)

# %%
cleaned_df

# %% [markdown]
# ## Task
#
# This is the dataset regarding unemployment in India for the year 2020. The code below loads the dataset and prints the head. We also see a barchart with count of records for each state. We see that two states have records missing. The column `region` is also duplicated. Using persIst extension to rename the columns, and then remove the two states which have missing records. Generate a dataframe from this, and then find three states with highest mean `estimated unemployment rate` for first quarter of 2020.
#
# #### Format of this task would be to select categories which have a high aggregate value of some quantity when grouped over other category.

# %%
df = pd.read_csv("./unemployment_india_2020.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("./unemployment_india_2020.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
selector = alt.selection_point(name="selector", encodings=["x"])

alt.Chart(df, name="bars").mark_bar().encode(x="Region:N",
            y="count()",
            color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
           ).add_params(selector)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
cleaned_df[" Date"] = pd.to_datetime(cleaned_df[" Date"]).dt.strftime("%B")
cleaned_df.head()
# Out:
#    index      Date   Estimated Employed  \
# 0      1   January             16635535
# 1      2  February             16545652
# 2      3     March             15881197
# 3      4     April             11336911
# 4      5       May             12988845
#
#     Estimated Labour Participation Rate (%)   Estimated Unemployment Rate (%)  \
# 0                                     41.02                              5.48
# 1                                     40.90                              5.83
# 2                                     39.18                              5.79
# 3                                     33.10                             20.51
# 4                                     36.46                             17.43
#
#    Frequency           State Region  latitude  longitude
# 0          M  Andhra Pradesh  South     79.74    15.9129
# 1          M  Andhra Pradesh  South     79.74    15.9129
# 2          M  Andhra Pradesh  South     79.74    15.9129
# ...

# %%
selector = alt.selection_point(name="selector", encodings=["x"])

alt.Chart(cleaned_df, name="bars").mark_bar().encode(
            x=alt.X(" Date:N").sort("x"),
            y="mean( Estimated Unemployment Rate (%)):Q",
            color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
           ).add_params(selector)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
first_qt

filtered_df = first_qt[first_qt["__selected"]]
filtered_df
# Out:
#      index      Date   Estimated Employed  \
# 0        1   January             16635535
# 1        2  February             16545652
# 2        3     March             15881197
# 10      11   January             13051904
# 11      12  February             10088268
# ..     ...       ...                  ...
# 231    249  February              3020931
# 232    250     March              2539302
# 240    258   January             35820789
# 241    259  February             36964178
# 242    260     March             35903917
#
#       Estimated Labour Participation Rate (%)  \
# 0                                       41.02
# 1                                       40.90
# 2                                       39.18
# 10                                      52.98
# 11                                      40.77
# ..                                        ...
# 231                                     36.48
# 232                                     36.27
# ...

# %%
selector = alt.selection_point(name="selector", encodings=["x"])

alt.Chart(filtered_df, name="bars").mark_bar().encode(
            x=alt.X("State:N").sort("-y"),
            y="mean( Estimated Unemployment Rate (%)):Q",
            color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
           ).add_params(selector)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
filtered_df.columns
# Out:
# Index(['index', ' Date', ' Estimated Employed',
#        ' Estimated Labour Participation Rate (%)',
#        ' Estimated Unemployment Rate (%)', ' Frequency', 'State', 'Region',
#        'latitude', 'longitude', '__selected'],
#       dtype='object')

# %%
alt.Chart(filtered_df).mark_point().encode(
    x=" Estimated Employed",
    y=" Estimated Unemployment Rate (%)",
)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
# have fallback dataframes, make it the end point
# List of features
# Test every feature in the study
# cover in the study, sheets in
# latin sq setup for the tasks
#  have some spread

# utah avalanche report datasets
# hw repository - wrangling datsaets
# spotty dataset to delete low values
# categorization

# Frank conference room

# accessible to people who are not data wrangling expert
