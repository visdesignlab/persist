# %%
import altair as alt
import pandas as pd

# Import the extension. This is the line that enables everything.
import persist_ext as PR

PR.enable('altair')
# Out:
# Loaded PersIst extension version 1.3.0
# Extension enabled for altair

# %%
df = pd.read_csv("./unemployment_india_2020.csv")
df.head()
# Out:
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  2020-01-31         M                             5.48
# 1  Andhra Pradesh  2020-02-29         M                             5.83
# 2  Andhra Pradesh  2020-03-31         M                             5.79
# 3  Andhra Pradesh  2020-04-30         M                            20.51
# 4  Andhra Pradesh  2020-05-31         M                            17.43
#
#    Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# 0            16635535                                    41.02    South
# 1            16545652                                    40.90    South
# 2            15881197                                    39.18    South
# 3            11336911                                    33.10    South
# 4            12988845                                    36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# 2    15.9129     79.74
# 3    15.9129     79.74
# 4    15.9129     79.74

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   267 non-null    object
#  1   Date                                     267 non-null    object
#  2   Frequency                                267 non-null    object
#  3   Estimated Unemployment Rate (%)          267 non-null    float64
#  4   Estimated Employed                       267 non-null    int64
#  5   Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                 267 non-null    object
#  7   longitude                                267 non-null    float64
#  8   latitude                                 267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %% [markdown]
# ## Task
#
# This is the dataset regarding unemployment in India for the year 2020. The code below loads the dataset and prints the head. We also see a barchart with count of records for each state. We see that two states have records missing. The column `region` is also duplicated. Using persIst extension to rename the columns, and then remove the two states which have missing records. Generate a dataframe from this, and then find three states with highest mean `estimated unemployment rate` for first quarter of 2020.
#
# #### Format of this task would be to select categories which have a high aggregate value of some quantity when grouped over other category.

# %%
df = pd.read_csv("./unemployment_india_2020.csv")
df
# Out:
#              Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh  2020-01-31         M                             5.48
# 1    Andhra Pradesh  2020-02-29         M                             5.83
# 2    Andhra Pradesh  2020-03-31         M                             5.79
# 3    Andhra Pradesh  2020-04-30         M                            20.51
# 4    Andhra Pradesh  2020-05-31         M                            17.43
# ..              ...         ...       ...                              ...
# 262     West Bengal  2020-06-30         M                             7.29
# 263     West Bengal  2020-07-31         M                             6.83
# 264     West Bengal  2020-08-31         M                            14.87
# 265     West Bengal  2020-09-30         M                             9.35
# 266     West Bengal  2020-10-31         M                             9.98
#
#      Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# 0              16635535                                    41.02    South
# 1              16545652                                    40.90    South
# 2              15881197                                    39.18    South
# 3              11336911                                    33.10    South
# 4              12988845                                    36.46    South
# ..                  ...                                      ...      ...
# 262            30726310                                    40.39     East
# 263            35372506                                    46.17     East
# 264            33298644                                    47.48     East
# 265            35707239                                    47.73     East
# 266            33962549                                    45.63     East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 9 columns]

# %%
# selector = alt.selection_point(name="selector", encodings=["x"])


# alt.Chart(df, name="bars").mark_bar().encode(x="Region:N",
#             y="count()",
#             color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
#            ).add_params(selector)

PR.vis.barchart(df, "Region:N", "count()")
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
cleaned_df
# Out:
#               State       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2020-01-31         M                             5.48
# 1    Andhra Pradesh 2020-02-29         M                             5.83
# 2    Andhra Pradesh 2020-03-31         M                             5.79
# 3    Andhra Pradesh 2020-04-30         M                            20.51
# 4    Andhra Pradesh 2020-05-31         M                            17.43
# ..              ...        ...       ...                              ...
# 262     West Bengal 2020-06-30         M                             7.29
# 263     West Bengal 2020-07-31         M                             6.83
# 264     West Bengal 2020-08-31         M                            14.87
# 265     West Bengal 2020-09-30         M                             9.35
# 266     West Bengal 2020-10-31         M                             9.98
#
#      Estimated Employed  Estimated Labour Participation Rate (%) Region  \
# 0              16635535                                    41.02  South
# 1              16545652                                    40.90  South
# 2              15881197                                    39.18  South
# 3              11336911                                    33.10  South
# 4              12988845                                    36.46  South
# ..                  ...                                      ...    ...
# 262            30726310                                    40.39   East
# 263            35372506                                    46.17   East
# 264            33298644                                    47.48   East
# 265            35707239                                    47.73   East
# 266            33962549                                    45.63   East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [250 rows x 9 columns]

# %%
# selector = alt.selection_point(name="selector", encodings=["x"])

# alt.Chart(cleaned_df, name="bars").mark_bar().encode(
#             x=alt.X("month(Date)").sort("x"),
#             y="mean( Estimated Unemployment Rate (%)):Q",
#             color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
#            ).add_params(selector)

PR.vis.barchart(cleaned_df, "month(Date):N", "mean(Estimated Unemployment Rate (%)):Q")
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
first_qt
# Out:
#               State       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2020-01-31         M                             5.48
# 1    Andhra Pradesh 2020-02-29         M                             5.83
# 2    Andhra Pradesh 2020-03-31         M                             5.79
# 10            Assam 2020-01-31         M                             4.66
# 11            Assam 2020-02-29         M                             4.41
# ..              ...        ...       ...                              ...
# 231     Uttarakhand 2020-02-29         M                             4.99
# 232     Uttarakhand 2020-03-31         M                            19.85
# 240     West Bengal 2020-01-31         M                             6.94
# 241     West Bengal 2020-02-29         M                             4.92
# 242     West Bengal 2020-03-31         M                             6.92
#
#      Estimated Employed  Estimated Labour Participation Rate (%)     Region  \
# 0              16635535                                    41.02      South
# 1              16545652                                    40.90      South
# 2              15881197                                    39.18      South
# 10             13051904                                    52.98  Northeast
# 11             10088268                                    40.77  Northeast
# ..                  ...                                      ...        ...
# 231             3020931                                    36.48      North
# 232             2539302                                    36.27      North
# 240            35820789                                    47.35       East
# 241            36964178                                    47.74       East
# 242            35903917                                    47.27       East
#
#      longitude  latitude
# 0      15.9129   79.7400
# 1      15.9129   79.7400
# 2      15.9129   79.7400
# 10     26.2006   92.9376
# 11     26.2006   92.9376
# ..         ...       ...
# 231    30.0668   79.0193
# 232    30.0668   79.0193
# 240    22.9868   87.8550
# 241    22.9868   87.8550
# 242    22.9868   87.8550
#
# [75 rows x 9 columns]

# %%
# selector = alt.selection_point(name="selector", encodings=["x"])

# alt.Chart(first_qt, name="bars").mark_bar().encode(
#             x=alt.X("State:N").sort("-y"),
#             y="mean( Estimated Unemployment Rate (%)):Q",
#             color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
#            ).add_params(selector)

PR.vis.barchart(first_qt, alt.X("State:N").sort("-y"), y="mean(Estimated Unemployment Rate (%)):Q", selection_type="point")
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
# have fallback dataframes, make it the end point
# List of features
# Test every feature in the study
# cover in the study, sheets in
# latin sq setup for the tasks
#  have some spread

# utah avalanche report datasets
# hw repository - wrangling datsaets
# spotty dataset to delete low values
# categorization

# Frank conference room

# accessible to people who are not data wrangling expert
