# %%
import altair as alt
import pandas as pd

# Import the extension. This is the line that enables everything.
import persist_ext as PR

PR.enable('altair')
# Out:
# Loaded PersIst extension version 1.2.0
# Extension enabled for altair

# %%
df = pd.read_csv("./unemployment_india_2020.csv")
df.head()
# Out:
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  2020-01-31         M                             5.48
# 1  Andhra Pradesh  2020-02-29         M                             5.83
# 2  Andhra Pradesh  2020-03-31         M                             5.79
# 3  Andhra Pradesh  2020-04-30         M                            20.51
# 4  Andhra Pradesh  2020-05-31         M                            17.43
#
#    Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# 0            16635535                                    41.02    South
# 1            16545652                                    40.90    South
# 2            15881197                                    39.18    South
# 3            11336911                                    33.10    South
# 4            12988845                                    36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# ...

# %%
interactions = [{"id":"fcaec9f6-196b-4553-bb59-bbf41b0a677f","type":"create"},{"id":"4abe6b99-d08b-4575-bc11-760416955a39","type":"selection","name":"selector","select":{"encodings":["x"],"type":"point"},"views":["bars"],"selected":{"value":[{"month_Date":1335855600000}],"encodingTypes":{"Date":{"field":"Date","sort":"x","timeUnit":"month","type":"temporal"},"Estimated Unemployment Rate (%)":{"aggregate":"mean","field":"Estimated Unemployment Rate (%)","type":"quantitative"}}}},{"id":"62421a51-b4e7-41f8-aa9e-23c89430c413","type":"selection","name":"selector","select":{"encodings":["x"],"type":"point"},"views":["bars"],"selected":{"value":[{"month_Date":1335855600000},{"month_Date":1333263600000}],"encodingTypes":{"Date":{"field":"Date","sort":"x","timeUnit":"month","type":"temporal"},"Estimated Unemployment Rate (%)":{"aggregate":"mean","field":"Estimated Unemployment Rate (%)","type":"quantitative"}}},"value":[{"month_Date":1335855600000}]}]
import json
interactions = json.dumps(interactions[0:2])

df = PR.apply(df.to_json(orient='records'), interactions)
df[df.__selected]
# Out:
# ####################
# create
# Applied set()
# ['__processed']
# ####################
# selection
# ['month'] 1335855600000
# ---------------
# <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'int'>
# 2020-01-31 00:00:00 1970-01-01 00:22:15.855600
# Match 1
# ---------------
# <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'int'>
# 2020-02-29 00:00:00 1970-01-01 00:22:15.855600
# Not Match month 2 1
# ---------------
# <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'int'>
# 2020-03-31 00:00:00 1970-01-01 00:22:15.855600
# Not Match month 3 1
# ---------------
# <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'int'>
# 2020-04-30 00:00:00 1970-01-01 00:22:15.855600
# Not Match month 4 1
# ---------------
# <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'int'>
# 2020-05-31 00:00:00 1970-01-01 00:22:15.855600
# Not Match month 5 1
# ---------------
# <class 'pandas._libs.tslibs.timestamps.Timestamp'> <class 'int'>
# ...

# %%
selector = alt.selection_point(name="selector", encodings=["x"])

alt.Chart(df, name="bars").mark_bar().encode(
            x=alt.X("month(Date):N"),
            y="mean(Estimated Unemployment Rate (%)):Q", 
            color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
           ).add_params(selector)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
test[test]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 test[test]
#
# NameError: name 'test' is not defined
