# %%
import altair as alt
import pandas as pd

# Import the extension. This is the line that enables everything.
import persist_ext as PR

PR.enable('altair')
# Out:
# Loaded PersIst extension version 1.3.0
# Extension enabled for altair

# %%
df = pd.read_csv("./unemployment_india_2020.csv")
df.head()
# Out:
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  2020-01-31         M                             5.48
# 1  Andhra Pradesh  2020-02-29         M                             5.83
# 2  Andhra Pradesh  2020-03-31         M                             5.79
# 3  Andhra Pradesh  2020-04-30         M                            20.51
# 4  Andhra Pradesh  2020-05-31         M                            17.43
#
#    Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# 0            16635535                                    41.02    South
# 1            16545652                                    40.90    South
# 2            15881197                                    39.18    South
# 3            11336911                                    33.10    South
# 4            12988845                                    36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# ...

# %%
interactions = [{"id":"64eb850a-73d8-4d01-aa40-39c90a4f8bdf","type":"create"},{"id":"f3e1a02a-bef4-4234-aa1c-71ffc7b6a024","type":"selection","name":"selector","select":{"type":"interval"},"views":["bars"],"selected":{"value":{"Estimated Employed":[11000000,28000000]},"encodingTypes":{"Estimated Employed":{"field":"Estimated Employed","type":"quantitative"},"Estimated Unemployment Rate (%)":{"aggregate":"mean","field":"Estimated Unemployment Rate (%)","type":"quantitative"}}}},{"id":"dedd36b9-0605-45c0-a1cb-60e047a1a531","type":"filter","direction":"out"}]
import json
interactions = json.dumps(interactions)

df2 = PR.get_pts_status(df.to_json(orient='records'), interactions)
df2
# Out:
# ####################
# create
# Applied set()
# ['__processed']
# ####################
# selection
# Applied {'selector'}
# ['__processed']
# ####################
# filter
# Applied set()
# ['__processed']
# <function display at 0x109444160> <class 'IPython.core.display.JSON'>
# Here

# %%
selector = alt.selection_interval(name="selector")

alt.Chart(df, name="bars").mark_point().encode(
            x=alt.X("Estimated Employed:Q"),
            y="Estimated Unemployment Rate (%):Q", 
            color=alt.condition(selector, alt.value('steelblue'), alt.value('grey'))
           ).add_params(selector)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting
