# %%
import altair as alt
from vega_datasets import data
import persist_ext as PR

# %% [markdown]
# Cars dataset.
#
# Scatterplot with Miles and Weight
#
# 2D brush

# %%
cars_df = data.cars()
cars_df.head()

# %%
import altair as alt
from vega_datasets import data
import persist_ext as PR

cars_df = data.cars() # Load cars dataset

brush = alt.selection_interval(name="selector") # Create a 2d brush

# create scatterplot and link to brush
scatterplot = alt.Chart(cars_df).mark_point().encode(
    x="Miles_per_Gallon:Q",
    y="Weight_in_lbs:Q",
    color=alt.condition(brush, alt.value("steelblue"), alt.value("gray"))
).add_params(
    brush
)

PR.PersistTable(cars_df)

# %%
movies_df

# %%
import altair as alt
from vega_datasets import data
import persist_ext as PR

source = data.movies()

brush = alt.selection_interval(name="selector") # Create a 2d brush

# create scatterplot and link to brush
scatterplot = alt.Chart(source).mark_point().encode(
    x="Worldwide_Gross:Q",
    y="IMDB_Rating:Q",
    color=alt.condition(brush, alt.value("steelblue"), alt.value("gray"))
).add_params(
    brush
)

PR.PersistChart(scatterplot)
# Out:
# PersistWidget(data_values=[{'__id_column': '1', 'Title': 'The Land Girls', 'US_Gross': 146083, 'Worldwide_Gros…

# %%
import altair as alt
from vega_datasets import data
import pandas as pd
import persist_ext as PR

source = data.movies()
source = source.query("1990 < @pd.to_datetime(Release_Date).dt.year < 2023")

brush = alt.selection_interval(name="selector") # Create a 2d brush

# create scatterplot and link to brush
barchart = alt.Chart(source).mark_bar().encode(
    x="utcyear(Release_Date):N",
    y="count()",
    color=alt.condition(brush, alt.value("steelblue"), alt.value("gray"))
).add_params(
    brush
)

PR.PersistChart(barchart)

# %%
import altair as alt
from vega_datasets import data
import persist_ext as PR

source = data.movies.url

pts = alt.selection_point(name="pts", encodings=['x'])

rect = alt.Chart(data.movies.url).mark_rect().encode(
    alt.X('IMDB_Rating:Q').bin(),
    alt.Y('Rotten_Tomatoes_Rating:Q').bin(),
    alt.Color('count()').scale(scheme='greenblue').title('Total Records')
)

circ = rect.mark_point().encode(
    alt.ColorValue('grey'),
    alt.Size('count()').title('Records in Selection')
).transform_filter(
    pts
)

bar = alt.Chart(source, width=550, height=200).mark_bar().encode(
    x='Major_Genre:N',
    y='count()',
    color=alt.condition(pts, alt.ColorValue("steelblue"), alt.ColorValue("grey"))
).add_params(pts)

composite = alt.vconcat(
    rect + circ,
    bar
).resolve_legend(
    color="independent",
    size="independent"
)

PR.PersistChart(composite, data=source)

# %%
persist_df_4.head()

# %%
import altair as alt
from vega_datasets import data

cars_df = data.cars() # Load cars dataset

brush = alt.selection_interval(name="selector") # Create a 2d brush

# create scatterplot and link to brush
scatterplot = alt.Chart(cars_df).mark_point().encode(
    x="Miles_per_Gallon:Q",
    y="Weight_in_lbs:Q",
    color=alt.condition(brush, alt.value("steelblue"), alt.value("gray"))
).add_params(
    brush
).properties(
    width=400,
    height=400
)

scatterplot
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data
import persist_ext as PR

cars_df = data.cars() # Load cars dataset

brush = alt.selection_interval(name="selector") # Create a 2d brush

# create scatterplot and link to brush
scatterplot = alt.Chart(cars_df).mark_point().encode(
    x="Miles_per_Gallon:Q",
    y="Weight_in_lbs:Q",
    color=alt.condition(brush, alt.value("steelblue"), alt.value("gray"))
).add_params(
    brush
)

PR.PersistChart(scatterplot)
# Out:
# PersistWidget(data_values=[{'__id_column': '1', 'Name': 'chevrolet chevelle malibu', 'Miles_per_Gallon': 18.0,…
