# %%
import altair as alt
from vega_datasets import data
import pandas as pd
import persist_ext as PR
import json

PR.enable('altair')
# Out:
# Loaded PersIst extension version 1.3.0
# Extension enabled for altair

# %%
url = data.cars()
PR.create_interactive_table(url)

# %%
ABC

# %%
PR.vis.scatterplot(url, "Miles_per_Gallon", "Weight_in_lbs:Q", selection_type="interval")
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
PR.vis.scatterplot(A_dyn, "Miles_per_Gallon", "Weight_in_lbs:Q")
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
import json

interactions = [{"id":"93133d07-ba9a-4dd2-8341-a972f7a96484","type":"create"},{"id":"4e77df88-d611-4767-8e60-fd0ed5af16c2","type":"selection","name":"selector","select":{"type":"interval","encodings":["x"]},"views":["base_chart","d30b9c3e-e6f1-4b18-8a18-62994ff0f750"],"selected":{"value":{"Cylinders":[5,6]},"encodingTypes":{"Cylinders":{"field":"Cylinders","type":"ordinal"},"Weight_in_lbs":{"aggregate":"mean","field":"Weight_in_lbs","type":"quantitative"}}}},{"id":"b105c7c1-e316-4d26-b73d-22d62903968e","type":"invert-selection"}]
interactions = json.dumps(interactions)

df = PR.apply(url.to_json(orient="records"), interactions, "index")
df[df.__invert_selected].shape, df[~df.__invert_selected].shape
