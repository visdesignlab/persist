# %%
from vega_datasets import data
import persist_ext as PR
import altair as alt

# %%
cars = data.cars()
df = PR.data.prepare(cars)
df.head()
# Out:
#    index                       Name  Miles_per_Gallon  Cylinders  \
# 0      1  chevrolet chevelle malibu              18.0          8
# 1      2          buick skylark 320              15.0          8
# 2      3         plymouth satellite              18.0          8
# 3      4              amc rebel sst              16.0          8
# 4      5                ford torino              17.0          8
#
#    Displacement  Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0         307.0       130.0           3504          12.0 1970-01-01    USA
# 1         350.0       165.0           3693          11.5 1970-01-01    USA
# 2         318.0       150.0           3436          11.0 1970-01-01    USA
# 3         304.0       150.0           3433          12.0 1970-01-01    USA
# 4         302.0       140.0           3449          10.5 1970-01-01    USA

# %%
# w = PR.vis.scatterplot(df, x="Miles_per_Gallon:Q", y="Weight_in_lbs")
# # w = PR.vis.barchart(df, x="Origin", y="mean(Miles_per_Gallon)")
# w
w = PR.vis.interactive_table(df)
w
# Out:
# TrrackableOutputWidget(body_widget=InteractiveTableWidget(df_columns_all=['index', 'Name', 'Miles_per_Gallon',…

# %%
PR.Out().clear_logs()
PR.Out().show_logs()
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
# # import altair with an abbreviated alias
# import altair as alt

# # load a sample dataset as a pandas DataFrame
# from vega_datasets import data
# cars = data.cars()
# cars2 = cars.query("10.75 <= Miles_per_Gallon <= 23.5 and 2972.5781250000005 <= Weight_in_lbs <= 4388.828125")
# # make the chart
# a = alt.Chart(cars2).mark_point().encode(
#     x='Horsepower:Q',
#     y='Miles_per_Gallon:Q',
#     color='Origin:N',
# )

# cars2

# %%
# cars_sub = cars.sample(n = 100)

# c = cars_sub.reset_index(drop=True)
# c

# %%
# w.body_widget.data = cars

# %%
cars["a"] = None
cars["a"] += "Hello"
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin    a
# 0         130.0           3504          12.0 1970-01-01     USA  NaN
# 1         165.0           3693          11.5 1970-01-01     USA  NaN
# 2         150.0           3436          11.0 1970-01-01     USA  NaN
# 3         150.0           3433          12.0 1970-01-01     USA  NaN
# 4         140.0           3449          10.5 1970-01-01     USA  NaN
# ..          ...            ...           ...        ...     ...  ...
# 401        86.0           2790          15.6 1982-01-01     USA  NaN
# 402        52.0           2130          24.6 1982-01-01  Europe  NaN
# 403        84.0           2295          11.6 1982-01-01     USA  NaN
# 404        79.0           2625          18.6 1982-01-01     USA  NaN
# 405        82.0           2720          19.4 1982-01-01     USA  NaN
#
# [406 rows x 10 columns]

# %%
import pandas as pd

s = pd.Series([1, 2, 3, 4])
{v: False for k,v in s.to_dict().items()}
# Out:
# {1: False, 2: False, 3: False, 4: False}

# %%
import numpy as np
a = np.full(10, False)

# %%
b = {(i+1): v for i,v in enumerate(a.tolist())}

# %%
import json
json.dumps(b)
# Out:
# '{"1": false, "2": false, "3": false, "4": false, "5": false, "6": false, "7": false, "8": false, "9": false, "10": false}'

# %%
cars.sort_values("Name")
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 103  amc ambassador brougham              13.0          8         360.0
# 9         amc ambassador dpl              15.0          8         390.0
# 73        amc ambassador sst              17.0          8         304.0
# 264              amc concord              19.4          6         232.0
# 322              amc concord              24.3          4         151.0
# ..                       ...               ...        ...           ...
# 402                vw pickup              44.0          4          97.0
# 204                vw rabbit              29.0          4          90.0
# 316                vw rabbit              41.5          4          98.0
# 332     vw rabbit c (diesel)              44.3          4          90.0
# 300         vw rabbit custom              31.9          4          89.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin    a
# 103       175.0           3821          11.0 1973-01-01     USA  NaN
# 9         190.0           3850           8.5 1970-01-01     USA  NaN
# 73        150.0           3672          11.5 1972-01-01     USA  NaN
# 264        90.0           3210          17.2 1978-01-01     USA  NaN
# 322        90.0           3003          20.1 1980-01-01     USA  NaN
# ..          ...            ...           ...        ...     ...  ...
# 402        52.0           2130          24.6 1982-01-01  Europe  NaN
# 204        70.0           1937          14.2 1976-01-01  Europe  NaN
# 316        76.0           2144          14.7 1980-01-01  Europe  NaN
# 332        48.0           2085          21.7 1980-01-01  Europe  NaN
# 300        71.0           1925          14.0 1979-01-01  Europe  NaN
#
# [406 rows x 10 columns]
