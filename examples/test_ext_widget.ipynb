# %%
from vega_datasets import data
import persist_ext as PR

# %%
cars = data.cars()
df = PR.data.prepare(cars)

# %%
w = PR.vis.scatterplot(df, x="Miles_per_Gallon:Q", y="Weight_in_lbs:Q", selection_type="interval")
w
# Out:
# TrrackableOutputWidget(body_widget=VegaLiteChartWidget(debounce_wait=200.0, param_names=['selector'], param_ob…

# %%
PR.Out().clear_logs()

# %%
PR.Out().show_logs()
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
w.body_widget.chart.params[0].value
# Out:
# Undefined

# %%
w.body_widget._chart.params[0].value
# Out:
# Undefined
