# %%
from vega_datasets import data
import persist_ext as PR
import altair as alt

# %%
cars = data.cars()
df = PR.data.prepare(cars)
df.head()
# Out:
#    index                       Name  Miles_per_Gallon  Cylinders  \
# 0      1  chevrolet chevelle malibu              18.0          8
# 1      2          buick skylark 320              15.0          8
# 2      3         plymouth satellite              18.0          8
# 3      4              amc rebel sst              16.0          8
# 4      5                ford torino              17.0          8
#
#    Displacement  Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0         307.0       130.0           3504          12.0 1970-01-01    USA
# 1         350.0       165.0           3693          11.5 1970-01-01    USA
# 2         318.0       150.0           3436          11.0 1970-01-01    USA
# 3         304.0       150.0           3433          12.0 1970-01-01    USA
# 4         302.0       140.0           3449          10.5 1970-01-01    USA

# %%
w = PR.vis.scatterplot(df, x="Miles_per_Gallon:Q", y="Weight_in_lbs")
# w = PR.vis.barchart(df, x="Origin", y="mean(Miles_per_Gallon)")
w
# Out:
# TrrackableOutputWidget(body_widget=VegaLiteChartWidget(debounce_wait=200.0, df_columns=['Name', 'Miles_per_Gal…

# %%
# w.body_widget.data = cars.sample(n = 100)
# w

# %%
PR.Out().clear_logs()

# %%
PR.Out().show_logs()
# Out:
# Output(layout=Layout(border_bottom='1px solid black', border_left='1px solid black', border_right='1px solid b…

# %%
# # import altair with an abbreviated alias
# import altair as alt

# # load a sample dataset as a pandas DataFrame
# from vega_datasets import data
# cars = data.cars()

# # make the chart
# a = alt.Chart("https://raw.githubusercontent.com/vega/vega/main/docs/data/cars.json").mark_point().encode(
#     x='Horsepower:Q',
#     y='Miles_per_Gallon:Q',
#     color='Origin:N',
# )

# a

# %%
cars_sub = cars.sample(n = 100)

c = cars_sub.reset_index(drop=True)
c
# Out:
#                          Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0              toyota corolla              29.0          4          97.0
# 1        citroen ds-21 pallas               NaN          4         133.0
# 2          mazda glc custom l              37.0          4          91.0
# 3          chevrolet chevette              30.5          4          98.0
# 4            oldsmobile omega              11.0          8         350.0
# ..                        ...               ...        ...           ...
# 95  chevrolet chevelle malibu              18.0          8         307.0
# 96              datsun 310 gx              38.0          4          91.0
# 97           ford galaxie 500              14.0          8         351.0
# 98            ford granada gl              20.2          6         200.0
# 99                amc matador              15.0          6         258.0
#
#     Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         75.0           2171          16.0 1975-01-01   Japan
# 1        115.0           3090          17.5 1970-01-01  Europe
# 2         68.0           2025          18.2 1982-01-01   Japan
# 3         63.0           2051          17.0 1977-01-01     USA
# 4        180.0           3664          11.0 1973-01-01     USA
# ..         ...            ...           ...        ...     ...
# 95       130.0           3504          12.0 1970-01-01     USA
# 96        67.0           1995          16.2 1982-01-01   Japan
# 97       153.0           4154          13.5 1971-01-01     USA
# 98        88.0           3060          17.1 1982-01-01     USA
# 99       110.0           3730          19.0 1975-01-01     USA
#
# [100 rows x 9 columns]
