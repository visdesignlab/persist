# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv("ca_fire.csv")

# %%
df
# Out:
#        OBJECTID   YEAR_ STATE AGENCY UNIT_ID FIRE_NAME   INC_NUM  \
# 0         21440  2020.0    CA    CDF     NEU    NELSON  00013212
# 1         21441  2020.0    CA    CDF     NEU   AMORUSO  00011799
# 2         21442  2020.0    CA    CDF     NEU    ATHENS  00018493
# 3         21443  2020.0    CA    CDF     NEU   FLEMING  00007619
# 4         21444  2020.0    CA    CDF     NEU  MELANESE  00008471
# ...         ...     ...   ...    ...     ...       ...       ...
# 21921     43907  2022.0    CA    LRA     VNC  CHAMBERS  00023419
# 21922     43908  2022.0    CA    LRA     VNC      MOON  00073287
# 21923     43909  2022.0    CA    USF     SHF     TEXAS  00000953
# 21924     43910  2022.0    CA    USF     KNF      ALEX  00006290
# 21925     43911  2022.0    CA    CDF     TGU    TULARE  00008878
#
#                    ALARM_DATE               CONT_DATE  CAUSE  ...  OBJECTIVE  \
# 0      2020/06/18 00:00:00+00  2020/06/23 00:00:00+00   11.0  ...        1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21926 entries, 0 to 21925
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OBJECTID        21926 non-null  int64
#  1   YEAR_           21849 non-null  float64
#  2   STATE           21926 non-null  object
#  3   AGENCY          21921 non-null  object
#  4   UNIT_ID         21907 non-null  object
#  5   FIRE_NAME       21802 non-null  object
#  6   INC_NUM         21002 non-null  object
#  7   ALARM_DATE      16578 non-null  object
#  8   CONT_DATE       9346 non-null   object
#  9   CAUSE           21902 non-null  float64
#  10  C_METHOD        9805 non-null   float64
#  11  OBJECTIVE       21732 non-null  float64
#  12  GIS_ACRES       21926 non-null  float64
#  13  COMMENTS        4102 non-null   object
#  14  COMPLEX_NAME    571 non-null    object
#  15  COMPLEX_INCNUM  534 non-null    object
#  16  IRWINID         332 non-null    object
# ...

# %%
df2 = df.dropna(thresh=10000, axis=1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21926 entries, 0 to 21925
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      21926 non-null  int64
#  1   YEAR_         21849 non-null  float64
#  2   STATE         21926 non-null  object
#  3   AGENCY        21921 non-null  object
#  4   UNIT_ID       21907 non-null  object
#  5   FIRE_NAME     21802 non-null  object
#  6   INC_NUM       21002 non-null  object
#  7   ALARM_DATE    16578 non-null  object
#  8   CAUSE         21902 non-null  float64
#  9   OBJECTIVE     21732 non-null  float64
#  10  GIS_ACRES     21926 non-null  float64
#  11  FIRE_NUM      17201 non-null  object
#  12  DECADES       16704 non-null  float64
#  13  SHAPE_Length  21926 non-null  float64
#  14  SHAPE_Area    21926 non-null  float64
# dtypes: float64(7), int64(1), object(7)
# memory usage: 2.5+ MB

# %%
df2.drop(columns=["INC_NUM", "ALARM_DATE", "OBJECTIVE", "GIS_ACRES"]).dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12060 entries, 489 to 21569
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      12060 non-null  int64
#  1   YEAR_         12060 non-null  float64
#  2   STATE         12060 non-null  object
#  3   AGENCY        12060 non-null  object
#  4   UNIT_ID       12060 non-null  object
#  5   FIRE_NAME     12060 non-null  object
#  6   CAUSE         12060 non-null  float64
#  7   FIRE_NUM      12060 non-null  object
#  8   DECADES       12060 non-null  float64
#  9   SHAPE_Length  12060 non-null  float64
#  10  SHAPE_Area    12060 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.1+ MB
