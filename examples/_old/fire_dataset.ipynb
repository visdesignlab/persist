# %%
import altair as alt
import persist_ext as PR
import pandas as pd

PR.enable('altair')
# Out:
# Loaded PersIst extension version 1.1.0
# Extension enabled for altair

# %%
df  = pd.read_csv("fire_later.csv")
df = df.sample(1000)
df
# Out:
#      STATE          COUNTY   LATITUDE   LONGITUDE  FIRE_SIZE  CAUSE_CODE  \
# 1508    MS      TISHOMINGO  34.523419  -88.221712       2.00         5.0
# 1070    SC  Hampton County  32.849998  -81.216667       0.30         2.0
# 4447    GA        Randolph  31.645847  -84.773819       2.33         5.0
# 4851    AL            Hale  32.968046  -87.547937       2.00         5.0
# 3130    KY           Knott  37.223000  -83.036000       1.00         9.0
# ...    ...             ...        ...         ...        ...         ...
# 2535    NY         ONTARIO  42.982092  -77.402364       0.10         1.0
# 8       WA              33  47.378333 -121.390000       0.10         4.0
# 3135    GA          Twiggs  32.760428  -83.489792       0.10         5.0
# 509     MS         NESHOBA  32.909098  -89.129772       1.00         5.0
# 2597    CO      Rio Blanco  39.784100 -108.772900       0.10         1.0
#
#          CAUSE_DESCR  DISCOVERY_DATE  DISCOVERY_TIME  CONT_DATE  CONT_TIME
# ...

# %%
pts = alt.selection_point(name="point_sel", encodings=['x'])

alt.Chart(df, width=550, height=200, name="bars").mark_bar().encode(
    x='STATE:N',
    y='count()',
    color=alt.condition(pts, alt.ColorValue("steelblue"), alt.ColorValue("grey"))
).add_params(pts)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
three_statest_agg
# Out:
#     STATE          COUNTY   LATITUDE   LONGITUDE  FIRE_SIZE  CAUSE_CODE  \
# 0      MS      TISHOMINGO  34.523419  -88.221712       2.00           5
# 1      SC  Hampton County  32.849998  -81.216667       0.30           2
# 2      GA        Randolph  31.645847  -84.773819       2.33           5
# 3      AL            Hale  32.968046  -87.547937       2.00           5
# 4      KY           Knott  37.223000  -83.036000       1.00           9
# ..    ...             ...        ...         ...        ...         ...
# 995    NY         ONTARIO  42.982092  -77.402364       0.10           1
# 996    WA              33  47.378333 -121.390000       0.10           4
# 997    GA          Twiggs  32.760428  -83.489792       0.10           5
# 998    MS         NESHOBA  32.909098  -89.129772       1.00           5
# 999    CO      Rio Blanco  39.784100 -108.772900       0.10           1
#
#         CAUSE_DESCR  DISCOVERY_DATE  DISCOVERY_TIME  CONT_DATE  CONT_TIME  \
# ...

# %%
# Out:
#     STATE          COUNTY   LATITUDE   LONGITUDE  FIRE_SIZE  CAUSE_CODE  \
# 0      MS      TISHOMINGO  34.523419  -88.221712       2.00           5
# 1      SC  Hampton County  32.849998  -81.216667       0.30           2
# 2      GA        Randolph  31.645847  -84.773819       2.33           5
# 3      AL            Hale  32.968046  -87.547937       2.00           5
# 4      KY           Knott  37.223000  -83.036000       1.00           9
# ..    ...             ...        ...         ...        ...         ...
# 995    NY         ONTARIO  42.982092  -77.402364       0.10           1
# 996    WA              33  47.378333 -121.390000       0.10           4
# 997    GA          Twiggs  32.760428  -83.489792       0.10           5
# 998    MS         NESHOBA  32.909098  -89.129772       1.00           5
# 999    CO      Rio Blanco  39.784100 -108.772900       0.10           1
#
#         CAUSE_DESCR  DISCOVERY_DATE  DISCOVERY_TIME  CONT_DATE  CONT_TIME  \
# ...

# %%
df_gen = three_statest_agg
df2 = df_gen[df_gen["__aggregate"] == "NM_NV_NY"]
df2
# Out:
#     STATE     COUNTY   LATITUDE   LONGITUDE  FIRE_SIZE  CAUSE_CODE  \
# 12     NY     Ulster  41.818100  -74.033300       1.00           9
# 15     NY    SUFFOLK  40.885152  -73.052510       0.10           9
# 18     NY       ERIE  42.736200  -78.530800       0.10           9
# 25     NY    GENESEE  42.898819  -78.031451       0.50           9
# 29     NY   New York  40.801800  -73.950000       0.10           9
# ..    ...        ...        ...         ...        ...         ...
# 980    NY   ROCKLAND  41.295600  -73.998100       0.10           9
# 985    NY  JEFFERSON  44.236353  -76.038676       0.50           7
# 991    NV         33  39.506944 -114.676667       0.10           1
# 994    NY    CLINTON  44.690659  -73.593777       0.68           9
# 995    NY    ONTARIO  42.982092  -77.402364       0.10           1
#
#        CAUSE_DESCR  DISCOVERY_DATE  DISCOVERY_TIME  CONT_DATE  CONT_TIME  \
# 12   Miscellaneous       2457131.5            1609  2457131.5       1748
# ...

# %%
pts2 = alt.selection_point(name="point_sel", encodings=['x'])

alt.Chart(df2, width=550, height=200, name="bars").mark_bar().encode(
    x='CAUSE_DESCR:N',
    y='count()',
    color=alt.condition(pts, alt.ColorValue("steelblue"), alt.ColorValue("grey"))
).add_params(pts2)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %%
alt.Chart(df2, width=550, height=200, name="bars").mark_bar().encode(
    x=alt.X('DISCOVERY_TIME:N', bin=True),
    y='count()',
)
# Out:
# <VegaLite 5 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/display_frontends.html#troubleshooting

# %% [markdown]
# Group state by region.  Select new england region
# - GEnerate a groupby dataframe
# -
