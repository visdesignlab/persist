# %%
import persist_ext as PR
import pathlib

# %%
w = PR.TrrackWidget()
w.test()
# Out:
# Hi <IPython.core.display.Javascript object>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Jupyter
#
# NameError: name 'Jupyter' is not defined
