# %%
import altair as alt
import pandas as pd
import panel as pn

import interactivede.ide as IDE # Our library
from interactivede.internal import *

IDE.enable('altair') # Call this to enable integration with altair
# Out:
# Extension enabled for altair

# %%
# pip install interactivede

# %%
penguins_url = "https://raw.githubusercontent.com/vega/vega/master/docs/data/penguins.json"

# %%
# All of the code here is pure altair. The library does not need any custom syntax

brush = alt.selection_interval(name='brush') # define a type of selection

# create a scatterplot
chart = alt.Chart(penguins_url).mark_point().encode(
    x=alt.X('Beak Length (mm):Q', scale=alt.Scale(zero=False)),
    y=alt.Y('Beak Depth (mm):Q', scale=alt.Scale(zero=False)),
    color=alt.condition(brush, 'Species:N', alt.value('lightgray'))
).properties(
    width=400,
    height=400
).add_selection(
    brush # Connect the brush selection to scatterplot
)

chart

# %%
# All of the code here is pure altair. The library does not need any custom syntax

brush2 = alt.selection_interval(name='brush') # define a type of selection

# create a scatterplot
chart = alt.Chart(penguins_url).mark_point().encode(
    x=alt.X('Beak Length (mm):Q', scale=alt.Scale(zero=False)),
    y=alt.Y('Beak Depth (mm):Q', scale=alt.Scale(zero=False)),
    color=alt.condition(brush, 'Species:N', alt.value('lightgray'))
).properties(
    width=400,
    height=400
).add_selection(
    brush2 # Connect the brush selection to scatterplot
)

chart

# %%
# use running number
# have a api func to return all dfs
# show preview on right click
# use annotations to show details of interaction
# if we can add/show annotations to df
# setup binder
# persist the df generation w/o extension
# copy code to clip
# get groupby agg
# agg vs groupby?
    # adding category
    # convex hulls for simple representatin
    # bubble sets
# move logseq task list to gh issues

ext_df
